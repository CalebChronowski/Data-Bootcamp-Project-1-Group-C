# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
young_data_to_load = "Resources/young_cdc_data.csv"
mid_data_to_load = "Resources/fig24.xlsx"
old_data_to_load = "Resources/fig25.xlsx"
cdc_to_load = "../Resources/CDC.csv"
# Read the Mouse and Drug Data and the Clinical Trial Data
yng_df = pd.read_csv(young_data_to_load) #skiprows=5)
mid_df = pd.read_excel(mid_data_to_load) #skiprows=5)
old_df = pd.read_excel(old_data_to_load) #skiprows=5)
# Combine the data into a single dataset
#cdc_data = pd.merge(yng_df, mid_df, old_df, on="Unnamed: 1")
cdc = pd.read_csv(cdc_to_load)

# Display the data table for preview

# %%
yng_df.columns
# Out:
# Index(['Data table for Figure 23. Death rates among children aged 1–14 years and persons aged 15–24 years, by leading causes of death: United States, 2006–2016',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='object')

# %%
mid_df.columns
# Out:
# Index(['Data table for Figure 24. Death rates among persons aged 25–44 and 45–64, by leading causes of death: United States, 2006–2016',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
old_df.columns
# Out:
# Index(['Data table for Figure 25. Death rates among persons aged 65 and over, by leading causes of death and for Alzheimer's disease: United States, 2006–2016',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %%
os.getcwd()
# Out:
# '/Users/danielmowbray/Documents/Data-Bootcamp-Project-1-Group-C'

# %%
cdc_df = pd.DataFrame(cdc)

# %%
cdc_df
# Out:
#                  Unnamed: 0        2006        2007        2008        2009  \
# 0                Alzhiemers   24.275093   24.775653   27.108397   25.753042
# 1                    Cancer  192.375551  191.573445  190.710459  189.793688
# 2         Traffic Accidents   15.981304   15.292904   13.782253   12.470192
# 3                  Diabetes   24.280790   23.696748   23.201052   22.396146
# 4             Heart Disease  210.702187  203.514107  201.887597  194.445359
# 5                       HIV    4.059590    3.749612    3.382178    3.066125
# 6                  Homicide    6.137478    6.017305    5.781108    5.394894
# 7            Kidney Disease    0.189356    0.177272    0.166725    0.169507
# 8   Lower Respitory Disease   41.753146   42.467048   46.396843   44.773712
# 9                  OverDose    9.226828    9.908004   10.232364   10.352330
# 10     Pneumonia Influenza    18.877276   17.500511   18.508753   17.502276
# ...

# %%
cdc_df.plot(x = "2006", y = "2016", kind = "scatter", title = "10 years")

# %%
index = cdc_df['''Unnamed: 0'].values

# %%
cdc_df.plot(x = "Unnamed: 0", y = "2016", kind = "bar", title = "2016")

# %%
cdc_df.plot(x = "Unnamed: 0", y = "2006", kind = "bar", title = "2006")

# %%
ax = plt.gca()
cdc_df.plot(kind='line',x='Unnamed: 0',y='2006',ax=ax)
cdc_df.plot(kind='line',x='Unnamed: 0',y='2016', color='red', ax=ax)
plt.show()

# %%
ax = plt.gca()
cdc_df.plot(kind='line',x='Unnamed: 0',y='2006',ax=ax)
cdc_df.plot(kind='line',x='Unnamed: 0',y='2012', color='red', ax=ax)
plt.show()

# %%
ax = plt.gca()
cdc_df.plot(kind='line',x='Unnamed: 0',y='2012',ax=ax)
cdc_df.plot(kind='line',x='Unnamed: 0',y='2016', color='red', ax=ax)
plt.show()
