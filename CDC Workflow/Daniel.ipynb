# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import pandas as pd
import numpy as np
import os
from itertools import cycle, islice
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

import seaborn

# %%
csv_to_load = "../Resources/joined.csv"
nyt_to_load = "../Resources/NYT.csv"
cdc_to_load = "../Resources/CDC.csv"
ggl_to_load = "../Resources/GOOG.csv"
cdcy_to_load = "../Resources/CDCYear.csv"
ggly_to_load = "../Resources/GOOGYear.csv"
nyty_to_load = "../Resources/NYTYear.csv"
csv = pd.read_csv(csv_to_load)
nyt = pd.read_csv(nyt_to_load)
cdc = pd.read_csv(cdc_to_load)
ggl = pd.read_csv(ggl_to_load)
cdcy = pd.read_csv(cdcy_to_load)
ggly = pd.read_csv(ggly_to_load)
nyty = pd.read_csv(nyty_to_load)

# %%
csv_df = pd.DataFrame(csv)
nyt_df = pd.DataFrame(nyt)
cdc_df = pd.DataFrame(cdc)
ggl_df = pd.DataFrame(ggl)
cdcy_df = pd.DataFrame(cdcy)
nyty_df = pd.DataFrame(nyty)
ggly_df = pd.DataFrame(ggly)

# %%
csv_df.head()
# Out:
#        causes  year        cdc  nyt   ggl
# 0  alzhiemers  2006  24.275093  531  61.3
# 1  alzhiemers  2007  24.775653  391  54.7
# 2  alzhiemers  2008  27.108397  361  55.0
# 3  alzhiemers  2009  25.753042  427  50.2
# 4  alzhiemers  2010  27.042982  313  32.8

# %%
nyt_df.head()
# Out:
#                causes   2006  2007  2008  2009  2010  2011  2012  2013  2014  \
# 0          alzheimers    531   391   361   427   313   302   333   298   303
# 1              cancer   4941  3055  3352  3504  2563  2487  2526  2250  2187
# 2  automobile_crashes    139   126   132   256   231   144   146   148   295
# 3            diabetes  1,141   733   762   779   595   447   536   522   463
# 4       heart_disease   1436  1004  1019   921   616   574   642   683   609
#
#    2015  2016
# 0   282   279
# 1  2184  2031
# 2   142   113
# 3   450   454
# 4   636   628

# %%
cdcy_df
# Out:
#     year  alzheimers      cancer  automobile_crashes   diabetes  \
# 0   2006   24.275093  192.375551           15.981304  24.280790
# 1   2007   24.775653  191.573445           15.292904  23.696748
# 2   2008   27.108397  190.710459           13.782253  23.201052
# 3   2009   25.753042  189.793688           12.470192  22.396146
# 4   2010   27.042982  190.985756           12.060417  22.371497
# 5   2011   27.270926  189.891961           11.964367  23.694774
# 6   2012   26.643281  190.395753           12.185183  23.551670
# 7   2013   26.814067  189.831779           11.762293  23.907341
# 8   2014   29.336343  190.599201           11.665102  23.988179
# 9   2015   34.397799  190.470178           12.343708  24.744973
# 10  2016   35.931016  189.965873           14.204820  24.775978
#
#     heart_disease  homicide  kidney_disease  lower_respiratory_disease  \
# 0      210.702187  6.137478        0.189356                  41.753146
# ...

# %%
ax = plt.gca()
cdcy_df.plot(kind='bar',x='year',y='overdose', color='red',ax=ax, figsize=(15,5))
cdcy_df.plot(kind='bar',x='year',y='automobile_crashes', color='blue',ax=ax, figsize=(15,5))
#ggly_df.plot(kind='line',x='years',y='overdose', color='brown',ax=ax, figsize=(15,5))
#ggly_df.plot(kind='line',x='years',y='automobile_crashes', color='green',ax=ax, figsize=(15,5))
#nyty_df.plot(kind='line',x='year',y='overdose', color='yellow',ax=ax, figsize=(15,5))
#nyty_df.plot(kind='line',x='year',y='automobile_crashes', color='orange',ax=ax, figsize=(15,5))
plt.title("CDC Overdose over Car CrashesBar")
plt.ylabel("Per 100,000")
plt.savefig("CDC Overdose over Crashes.png")
plt.show()

# %%
ax = plt.gca()
cdcy_df.plot(kind='line',x='year',y='kidney_disease', color='red',ax=ax, figsize=(15,5))
cdcy_df.plot(kind='line',x='year',y='terrorism', color='blue',ax=ax, figsize=(15,5))
#cdcy_df.plot(kind='line',x='year',y='stroke', color='green',ax=ax, figsize=(15,5))
#ggly_df.plot(kind='line',x='years',y='heart_disease', color='brown',ax=ax, figsize=(15,5))
#ggly_df.plot(kind='line',x='years',y='cancer', color='green',ax=ax, figsize=(15,5))
#nyty_df.plot(kind='line',x='year',y='heart_disease', color='yellow',ax=ax, figsize=(15,5))
#nyty_df.plot(kind='line',x='year',y='cancer', color='orange',ax=ax, figsize=(15,5))
plt.title("CDC Disease over Cancer")
plt.ylabel("Per 100,000")
plt.savefig("CDC Heart Disease over Cancer.png")
plt.show()

# %%
ax = plt.gca()
cdcy_df.plot(kind='line',x='year',y='heart_disease', color='red',ax=ax, figsize=(15,5))
cdcy_df.plot(kind='line',x='year',y='cancer', color='blue',ax=ax, figsize=(15,5))
#cdcy_df.plot(kind='line',x='year',y='stroke', color='green',ax=ax, figsize=(15,5))
#ggly_df.plot(kind='line',x='years',y='heart_disease', color='brown',ax=ax, figsize=(15,5))
#ggly_df.plot(kind='line',x='years',y='cancer', color='green',ax=ax, figsize=(15,5))
#nyty_df.plot(kind='line',x='year',y='heart_disease', color='yellow',ax=ax, figsize=(15,5))
#nyty_df.plot(kind='line',x='year',y='cancer', color='orange',ax=ax, figsize=(15,5))
plt.title("CDC Heart Disease over Cancer")
plt.ylabel("Per 100,000")
plt.savefig("CDC Heart Disease over Cancer.png")
plt.show()

# %%
plt.plot('year', 'overdose', data=cdcy_df) 
plt.plot('year', 'overdose', data=nyty_df)

# %%
cdcy_df.plot(kind='line',x='year',y='heart_disease', color='green',ax=ax, figsize=(15,5))

# %%
cdc_dft = cdc_df.set_index('Causes')

# %%
cdc_dft.head()
# Out:
#                           2006        2007        2008        2009  \
# Causes
# alzheimers           24.275093   24.775653   27.108397   25.753042
# cancer              192.375551  191.573445  190.710459  189.793688
# automobile_crashes   15.981304   15.292904   13.782253   12.470192
# diabetes             24.280790   23.696748   23.201052   22.396146
# heart_disease       210.702187  203.514107  201.887597  194.445359
#
#                           2010        2011        2012        2013  \
# Causes
# alzheimers           27.042982   27.270926   26.643281   26.814067
# cancer              190.985756  189.891961  190.395753  189.831779
# automobile_crashes   12.060417   11.964367   12.185183   11.762293
# diabetes             22.371497   23.694774   23.551670   23.907341
# heart_disease       192.667724  190.278042  189.786988  192.025505
#
#                           2014        2015        2016
# Causes
# alzheimers           29.336343   34.397799   35.931016
# ...

# %%
ggl_df.head()
# Out:
#                Causes         2004         2005         2006         2007  \
# 0          alzheimers    76.900000    66.300000    61.300000    54.700000
# 1              cancer  2357.941725  2315.379600  2199.043125  2136.618675
# 2  automobile_crashes    11.833314     8.249987     7.624988     4.854159
# 3            diabetes   720.403375   706.216000   665.230250   631.338188
# 4       heart_disease   135.743575   124.884089   110.521543    98.611139
#
#           2008         2009         2010         2011         2012  \
# 0    55.000000    50.200000    32.800000    37.300000    29.600000
# 1  2113.918875  2159.318475  2042.982000  2122.431300  2133.781200
# 2     4.062493     3.999994     2.562496     2.187496     1.541664
# 3   613.209875   607.692563   594.293375   577.741437   573.800500
# 4    93.181396    97.735374    89.152877    90.729254    92.655937
#
#           2013         2014         2015         2016         2017  \
# ...

# %%
ax = csv_df.plot.bar(x='causes', rot=0)
plt.show()

# %%
axes = csv_df.plot.bar(rot=0, subplots=True)
axes[1].legend(loc=0)

# %%
axq = cdc_df.plot.bar(y='2016', rot=0)
axr = cdc_df.plot.line(y='2012', rot=0)
plt.show()

# %%
ax = plt.gca()
cdc_df.plot(kind='bar',x='Causes',y='2016', color='blue',ax=ax)
cdc_df.plot(kind='bar',x='Causes',y='2014', color='red',ax=ax, figsize=(15,5))
cdc_df.plot(kind='bar',x='Causes',y='2012', color='orange',ax=ax)
cdc_df.plot(kind='bar',x='Causes',y='2012', color='yellow', ax=ax, figsize=(15,5))
cdc_df.plot(kind='bar',x='Causes',y='2010', color='purple', ax=ax)
cdc_df.plot(kind='bar',x='Causes',y='2009', color='gray', ax=ax)
cdc_df.plot(kind='bar',x='Causes',y='2008', color='pink', ax=ax, figsize=(15,5))
cdc_df.plot(kind='bar',x='Causes',y='2007', color='indigo', ax=ax, figsize=(15,5))
cdc_df.plot(kind='bar',x='Causes',y='2006', color='green', ax=ax)

plt.show()

# %%
colours = ['r', 'b','g','y','m','c'][0:len(cdc_df.columns)]
ax = plt.gca()
cdc_df.plot(kind='line',x='Causes',y='2016', color='gray',ax=ax)
cdc_df.plot(kind='line',x='Causes',y='2015', color='purple', ax=ax)
cdc_df.plot(kind='line',x='Causes',y='2014', color='magenta',ax=ax, figsize=(15,5))
cdc_df.plot(kind='line',x='Causes',y='2013', color='yellow',ax=ax)
cdc_df.plot(kind='line',x='Causes',y='2012', color='red',ax=ax)
cdc_df.plot(kind='line',x='Causes',y='2011', color='pink', ax=ax, figsize=(15,5))
cdc_df.plot(kind='line',x='Causes',y='2010', color='orange', ax=ax)
cdc_df.plot(kind='line',x='Causes',y='2009', color='gold',ax=ax)
cdc_df.plot(kind='line',x='Causes',y='2008', color='aquamarine', ax=ax, figsize=(25,15))
cdc_df.plot(kind='line',x='Causes',y='2007', color='green',ax=ax)
cdc_df.plot(kind='line',x='Causes',y='2006', color='blue', ax=ax)
plt.title("CDC Total Cause of Death Change")
plt.ylabel("Per 100,000")
plt.savefig("CDC Total Cause of Death Change.png")
plt.show()

# %%
cdcy_df.columns
# Out:
# Index(['year', 'alzheimers', 'cancer', 'automobile_crashes', 'diabetes',
#        'heart_disease', 'homicide', 'kidney_disease',
#        'lower_respiratory_disease', 'overdose', 'pnuemonia_and_influenza',
#        'stroke', 'suicide', 'terrorism'],
#       dtype='object')

# %%
colours = ['r', 'b','g','y','m','c'][0:len(cdc_df.columns)]
ax = plt.gca()
cdcy_df.plot(kind='line',x='year',y='alzheimers', color=colours,ax=ax)
cdcy_df.plot(kind='line',x='year',y='cancer', color=colours, ax=ax)
cdcy_df.plot(kind='line',x='year',y='automobile_crashes', color=colours,ax=ax, figsize=(15,5))
cdcy_df.plot(kind='line',x='year',y='diabetes', color=colours,ax=ax)
cdcy_df.plot(kind='line',x='year',y='heart_disease', color=colours,ax=ax)
cdcy_df.plot(kind='line',x='year',y='homicide', color=colours, ax=ax, figsize=(15,5))
cdcy_df.plot(kind='line',x='year',y='kidney_disease', color=colours, ax=ax)
cdcy_df.plot(kind='line',x='year',y='lower_respiratory_disease', color=colours,ax=ax)
cdcy_df.plot(kind='line',x='year',y='overdose', color=colours, ax=ax, figsize=(25,15))
cdcy_df.plot(kind='line',x='year',y='pnuemonia_and_influenza', color=colours,ax=ax)
cdcy_df.plot(kind='line',x='year',y='stroke', color=colours, ax=ax)
cdcy_df.plot(kind='line',x='year',y='suicide', color=colours, ax=ax)
cdcy_df.plot(kind='line',x='year',y='terrorism', color=colours, ax=ax)
plt.title("CDC Total Cause of Death Change over year")
plt.ylabel("Per 100,000")
plt.savefig("CDC Total Cause of Death Change over year.png")
plt.show()

# %%
ax = plt.gca()
ggl_df.plot(kind='line',x='Causes',y='2016', color='blue',ax=ax)
ggl_df.plot(kind='line',x='Causes',y='2014', color='red',ax=ax, figsize=(15,5))
ggl_df.plot(kind='line',x='Causes',y='2012', color='orange',ax=ax)
ggl_df.plot(kind='line',x='Causes',y='2012', color='yellow', ax=ax, figsize=(15,5))
ggl_df.plot(kind='line',x='Causes',y='2010', color='purple', ax=ax)
ggl_df.plot(kind='line',x='Causes',y='2008', color='green', ax=ax, figsize=(20,10))
ggl_df.plot(kind='line',x='Causes',y='2006',color='pink', ax=ax)
plt.show()

# %%
ax = plt.gca()
cdc_dft.plot(kind='line',y='2016', color='blue',ax=ax)
cdc_dft.plot(kind='line',y='2014', color='red',ax=ax, figsize=(15,5))
cdc_dft.plot(kind='line',y='2012', color='orange',ax=ax)
cdc_dft.plot(kind='line',y='2012', color='yellow', ax=ax, figsize=(15,5))
cdc_dft.plot(kind='line',y='2010', color='purple', ax=ax)
cdc_dft.plot(kind='line',y='2008', color='green', ax=ax, figsize=(25,15))
cdc_dft.plot(kind='line',y='2006', color='pink', ax=ax)
plt.show()

# %%
csv_df.plot('causes',['cdc','nyt','ggl'],kind = 'bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax = plt.gca()
nyt_df.plot(kind='line',x='causes',y='2016', color='blue',ax=ax)
nyt_df.plot(kind='line',x='causes',y='2014', color='red',ax=ax, figsize=(15,5))
nyt_df.plot(kind='line',x='causes',y='2012', color='orange',ax=ax)
nyt_df.plot(kind='line',x='causes',y='2012', color='yellow', ax=ax, figsize=(15,5))
nyt_df.plot(kind='line',x='causes',y='2010', color='purple', ax=ax)
nyt_df.plot(kind='line',x='causes',y='2008', color='green', ax=ax, figsize=(20,10))
nyt_df.plot(kind='line',x='causes',y='2007', color='pink', ax=ax, figsize=(20,10))
plt.show()

# %%
ax = plt.gca()
cdc_df.plot(kind='scatter',y='2006',x='2016',  color='blue', ax=ax, )
plt.show()

# %%
fig, ax = plt.subplots()
csv_df.groupby('causes').plot(kind='scatter',x='year',y='cdc', color='green', ax=ax, legend=True, figsize=(20,10))
csv_df.groupby('causes').plot(kind='scatter',x='year',y='ggl', color='blue', ax=ax, legend=True, figsize=(20,10))
# Out:
# causes
# alzhiemers                   AxesSubplot(0.125,0.125;0.775x0.755)
# automobile_crashes           AxesSubplot(0.125,0.125;0.775x0.755)
# cancer                       AxesSubplot(0.125,0.125;0.775x0.755)
# causes                       AxesSubplot(0.125,0.125;0.775x0.755)
# diabetes                     AxesSubplot(0.125,0.125;0.775x0.755)
# heart_disease                AxesSubplot(0.125,0.125;0.775x0.755)
# homicide                     AxesSubplot(0.125,0.125;0.775x0.755)
# kidney_disease               AxesSubplot(0.125,0.125;0.775x0.755)
# lower_respiratory_disease    AxesSubplot(0.125,0.125;0.775x0.755)
# overdose                     AxesSubplot(0.125,0.125;0.775x0.755)
# pnuemonia_and_influenza      AxesSubplot(0.125,0.125;0.775x0.755)
# stroke                       AxesSubplot(0.125,0.125;0.775x0.755)
# suicide                      AxesSubplot(0.125,0.125;0.775x0.755)
# terrorism                    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
seaborn.set(style='ticks')
fg = seaborn.FacetGrid(data=csv_df, hue='causes', hue_order='causes', aspect=1.61)
fg.map(plt.scatter, 'year', 'cdc').add_legend()

# %%
lines = plt.plot(x1, y1, x2, y2)
# use keyword args
plt.setp(lines, color='r', linewidth=2.0)
# or MATLAB style string value pairs
plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-9ef1f096dff6> in <module>
# ----> 1 lines = plt.plot(x1, y1, x2, y2)
#       2 # use keyword args
#       3 plt.setp(lines, color='r', linewidth=2.0)
#       4 # or MATLAB style string value pairs
#       5 plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
#
# NameError: name 'x1' is not defined

# %%
fig, ax = plt.subplots()
csv_df.groupby('causes').plot(kind='scatter',x='year',y='ggl', ax=ax, legend=True)

# %%
fig, ax = plt.subplots()
cdc_df.groupby('Causes').plot(x='2016', y='2012', ax=ax, legend=False)

# %%
ax = cdc_df.plot.bar(y='2016', rot=0, index='Causes')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-55f76772e9cc> in <module>
# ----> 1 ax = cdc_df.plot.bar(y='2016', rot=0, index='Causes')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwds)
#    3089             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    3090         """
# -> 3091         return self(kind='bar', x=x, y=y, **kwds)
#    3092
#    3093     def barh(self, x=None, y=None, **kwds):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
ax = plt.gca()
#csv_df.plot(kind='line',x='causes',y='ggl', color='blue', ax=ax)
#csv_df.plot(kind='line',x='causes',y='cdc', color='red', ax=ax)
#csv_df.plot(kind='line',x='causes',y='nyt', color='yellow', ax=ax)
plt.show()

# %%
cdc_df.groupby('2012')['Causes'].plot(kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
csv_df.plot(x = "causes", y = "year", kind = "bar", title = "2016")

# %%
csv_df.groupby('causes')['nyt'].nunique().plot(kind='bar')
plt.show()

# %%
csv_df.assign(dummy = 1).groupby(
  ['dummy','causes']).size().to_frame().unstack().plot(kind='bar',stacked=True,legend=False)

plt.title('Number of records by State')

# other it'll show up as 'dummy' 
plt.xlabel('')

# disable ticks in the x axis
plt.xticks([])

# fix the legend
current_handles, _ = plt.gca().get_legend_handles_labels()
reversed_handles = reversed(current_handles)

labels = reversed(csv_df['causes'].unique())

plt.legend(reversed_handles,labels,loc='lower right')
plt.show()
