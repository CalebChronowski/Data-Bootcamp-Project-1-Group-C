# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x_axis = [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
alzheimers = [61.3, 54.7, 55, 50.2, 32.8, 37.3, 29.6, 24, 26.6, 30.8, 34.9]
cancer = [77.5, 75.3, 74.5, 76.1, 72, 74.8, 75.2, 74.3, 74.1, 76.8, 76.6,]
automobile_crashes = [36.6, 23.3, 19.5, 19.2, 12.3, 10.5, 7.4, 7.3, 8.2, 8.8, 10.8]
diabetes = [84.4, 80.1, 77.8, 77.1, 75.4, 73.3, 72.8, 73.1, 74.6, 76.5, 73.8]
heart_disease = [63.1, 56.3, 53.2, 55.8, 50.9, 51.8, 52.9, 50, 51.1, 50.8, 50.7]
pnuemonia = [67.9, 63.3, 59.2, 44.7, 31.4, 32.3, 25.6, 21, 20.7, 22.5, 23.5]
influenza = [19.3, 14.6, 16.3, 37.3, 10.8, 11.8, 11.4, 14.8, 15.4, 14.4, 13]
terrorism = [43, 32.9, 28.3, 25.2, 23.9, 21.8, 17.9, 18.7, 18.2, 26.8, 25.3]


df =  pd.DataFrame({"Year":x_axis, 
                    "Alzheimers": alzheimers,
                    "Cancer": cancer,
                    "Automobile Crashes": automobile_crashes,
                    "Diabetes": diabetes,
                    "Heart Disease": heart_disease,
                    "Pnuemonia": pnuemonia,
                    "Influenza": influenza,
                    "Terrorism": terrorism
                   })

GRAPH = df.plot(x = "Year", y = ["Alzheimers", "Cancer",  "Automobile Crashes", "Diabetes", "Heart Disease", "Pnuemonia", "Influenza", "Terrorism"])


plt.savefig("rpm google declines.png")

# %%
x_axis = [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
homicide = [46.5, 52.8, 54.8, 56, 51, 64, 68.6, 77.2, 78, 79.9, 86.9]
kidney_disease = [53.8, 53.4, 54.3, 57.8, 57.6, 58.7, 63.2, 63.8, 66.9, 73.3, 76.3]
lower_respiratory_disease = [14.5, 18.8, 17.8, 15.1, 18.1, 10.8, 12.9, 11.8, 15.7, 14.9, 18]
overdose = [36.9, 38.9, 41.9, 45.4, 48.3, 50.2, 49.1, 48.6, 54.1, 51.1, 57.4]
stroke = [60.9, 57.1, 58.5, 57.9, 60, 69.1, 67.3, 68, 70.3, 75.3, 80.8]
suicide = [18.8, 17.7, 17.8, 17, 16.8, 17.2, 18.5, 17.8, 18.6, 22.3, 35.6]


df =  pd.DataFrame({"Year":x_axis, 
                    "Homicide": homicide,
                    "Kidney Disease": kidney_disease,
                    "Lower Respiratory Disease": lower_respiratory_disease,
                    "Overdose": overdose,
                    "Stroke": stroke,
                    "Suicide": suicide
                   })

GRAPH = df.plot(x = "Year", y = ["Homicide", "Kidney Disease",  "Lower Respiratory Disease", "Overdose", "Stroke", "Suicide"])


plt.savefig("rpm google increases.png")
